# %% [markdown]
# # Extract openbenchmarking.org results

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import os

# %% [markdown]
# # Step 1 : list the different urls of openbenchmarking.org
#
# 1 url = 1 test profile

# %%
parser = BeautifulSoup(open("./data/pages/test_profile.html").read(), 'html.parser')

listing = [p for p in parser.find_all('div', class_='row')]

lines = []

for l in listing:
    
    content = l.findChildren('div', class_='col-sm-6', recursive=False)
    
    name = None
    url = None
    type_pts = None
    description = None
    
    if len(content) > 0:
        first  = content[0].findChildren("a")[0]
        name, url = first.get_text(), first.get("href")
        type_pts = content[1].findChildren("h4")[0].get_text()
    
    content12 = l.findChildren('div', class_='col-sm-12', recursive=False)
    
    if len(content12) > 0:
        d = content12[0].findChildren('span')
        if len(d) > 0:
            description = d[0].get_text().replace(",","").replace("\n", "")
    
    lines.append((name, description, type_pts, url))

df = pd.DataFrame(lines).dropna()
df.columns = ["name", "description", "type", "url"]
df.to_csv("./data/list_urls.csv")
df
# Out:
#                                name  \
# 2                AI Benchmark Alpha
# 3                       Aircrack-ng
# 4    Algebraic Multi-Grid Benchmark
# 5                           AOBench
# 6                           AOM AV1
# ..                              ...
# 466                         Xsbench
# 467                  Xsbench OpenCL
# 468                      Y-Cruncher
# 469                         YafaRay
# 470                         yquake2
#
#                                            description       type  \
# 2    AI Benchmark Alpha is a Python library for eva...     System
# 3    Aircrack-ng is a tool for assessing WiFi/WLAN ...  Processor
# 4    AMG is a parallel algebraic multigrid solver f...  Processor
# 5    AOBench is a lightweight ambient occlusion ren...  Processor
# 6    This is a test of the AOMedia AV1 encoder (lib...  Processor
# ..                                                 ...        ...
# 466  XSBench is a mini-app representing a key compu...     System
# 467           Xsbench benchmark in OpenCL via GPUOpen.     System
# 468       Y-Cruncher is a multi-threaded Pi benchmark.  Processor
# 469  YafaRay is an open-source physically based mon...  Processor
# 470                  This is a test of Yamagi Quake II   Graphics
#
#                                                    url
# 2    https://openbenchmarking.org/test/pts/ai-bench...
# 3    https://openbenchmarking.org/test/pts/aircrack-ng
# 4            https://openbenchmarking.org/test/pts/amg
# 5        https://openbenchmarking.org/test/pts/aobench
# 6        https://openbenchmarking.org/test/pts/aom-av1
# ..                                                 ...
# 466      https://openbenchmarking.org/test/pts/xsbench
# 467   https://openbenchmarking.org/test/pts/xsbench-cl
# 468   https://openbenchmarking.org/test/pts/y-cruncher
# 469      https://openbenchmarking.org/test/pts/yafaray
# 470      https://openbenchmarking.org/test/pts/yquake2
#
# [469 rows x 4 columns]

# %% [markdown]
# # Step 2 : Extract the content of test profiles
#
# Input :
# - url of the webpage
#
# Output :
# - dataset of performances related to the system under test

# %%
class ExtractorTP():
    # input : the url of an openbenchmarking.org webpage
    # output : a dataframe containing the average performances for a configurable system
    
    def __init__(self, url):
        self.url = url
        html_text = requests.get(self.url).text
        self.parser = BeautifulSoup(html_text, 'html.parser')
        # to remove the "Low-Tier"-like lines
        self.banwords = ["Low-Tier", "Median", "Mid-Tier"]
    
    def extract_data(self):
        row_text = self.parser.find_all('div', class_='div_table_row')
        lines = [self.extract_row(rt) for rt in row_text]
        df = pd.DataFrame(lines).dropna()
        df.columns = ["idproc", "descproc", "percentile", "nbproc", "perf"]
        return df
        
    def extract_row(self, row_text):
        content_line = []
        cells = row_text.find_all('div', class_='div_table_cell')
        if cells[0].get_text() not in self.banwords:
            if cells[0].find("a"):
                content_line.append(cells[0].findChildren("a")[0].get("href"))
            else:
                content_line.append("")
            content_line.extend([c.get_text() for c in cells])
        return content_line

# %% [markdown]
# ### Test with x264

# %%
ext = ExtractorTP('https://openbenchmarking.org/test/pts/x264')
ext.extract_data()
# Out:
#                            idproc                   descproc percentile  \
# 0        /s/AMD+EPYC+7763+64-Core      AMD EPYC 7763 64-Core      100th
# 1        /s/AMD+EPYC+75F3+32-Core      AMD EPYC 75F3 32-Core      100th
# 2        /s/AMD+EPYC+7713+64-Core      AMD EPYC 7713 64-Core       99th
# 3    /s/2+x+AMD+EPYC+75F3+32-Core  2 x AMD EPYC 75F3 32-Core       99th
# 4    /s/2+x+AMD+EPYC+7713+64-Core  2 x AMD EPYC 7713 64-Core       99th
# ..                            ...                        ...        ...
# 176   /s/Intel+Pentium+Dual+E2220   Intel Pentium Dual E2220        6th
# 177    /s/ARMv8+Cortex-A55+4-Core    ARMv8 Cortex-A55 4-Core        5th
# 178   /s/Intel+Pentium+Dual+T2310   Intel Pentium Dual T2310        4th
# 179    /s/ARMv7+Cortex-A53+4-Core    ARMv7 Cortex-A53 4-Core        4th
# 180    /s/Mobile+AMD+Sempron+3500    Mobile AMD Sempron 3500        3rd
#
#     nbproc        perf
# 0        6   236 +/- 3
# 1        8  229 +/- 11
# 2        6   225 +/- 2
# 3       13  223 +/- 28
# 4        7   222 +/- 3
# ..     ...         ...
# 176      3           5
# 177      3           4
# 178      7           3
# 179      3           2
# 180     24           2
#
# [178 rows x 5 columns]

# %% [markdown]
# ### Test with x265

# %%
ext = ExtractorTP('https://openbenchmarking.org/test/pts/x265')
ext.extract_data()
# Out:
#                           idproc                  descproc percentile nbproc  \
# 0       /s/AMD+EPYC+75F3+32-Core     AMD EPYC 75F3 32-Core      100th      9
# 1    /s/Intel+Xeon+Platinum+8380  Intel Xeon Platinum 8380      100th      6
# 2       /s/AMD+EPYC+7643+48-Core     AMD EPYC 7643 48-Core      100th      3
# 3       /s/AMD+EPYC+7763+64-Core     AMD EPYC 7763 64-Core       99th     14
# 4       /s/AMD+EPYC+74F3+24-Core     AMD EPYC 74F3 24-Core       98th      6
# ..                           ...                       ...        ...    ...
# 154        /s/Intel+Core+i3-4130        Intel Core i3-4130        7th      3
# 155         /s/AMD+A10-7850K+APU         AMD A10-7850K APU        7th      6
# 156         /s/AMD+Ryzen+3+3200U         AMD Ryzen 3 3200U        6th      3
# 157             /s/POWER9+4-Core             POWER9 4-Core        4th      7
# 158       /s/Intel+Pentium+E5200       Intel Pentium E5200        3rd      4
#
#              perf
# 0    31.6 +/- 0.3
# 1            31.2
# 2    30.1 +/- 0.3
# 3    30.0 +/- 0.7
# 4    29.3 +/- 0.1
# ..            ...
# 154           2.8
# 155   2.6 +/- 0.1
# 156           2.6
# 157           1.3
# 158           0.7
#
# [156 rows x 5 columns]

# %% [markdown]
# # Step 3 : Extract the description of processors

# %%
class ExtractorPROC():
    # input : the url of an openbenchmarking.org webpage listing the technical details of a processor
    # output : a dataframe containing the average performances for a configurable system
    
    def __init__(self, url):
        self.url = url
        html_text = requests.get(self.url).text
        self.parser = BeautifulSoup(html_text, 'html.parser')
    
    def extract_data(self):
        row_text = self.parser.find_all('pre')
        lines = [rt.get_text() for rt in row_text]
        return lines

# %% [markdown]
# ### Test with one processor

# %%
ext = ExtractorPROC('https://openbenchmarking.org/s/AMD+EPYC+74F3+24-Core')
catproc, lscpu = ext.extract_data()
print(catproc)
# Out:
# processor	: 0
# vendor_id	: AuthenticAMD
# cpu family	: 25
# model		: 1
# model name	: AMD EPYC 74F3 24-Core Processor
# stepping	: 1
# microcode	: 0xa001119
# cpu MHz		: 3200.000
# cache size	: 512 KB
# physical id	: 0
# siblings	: 48
# core id		: 0
# cpu cores	: 24
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 16
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ht syscall nx mmxext fxsr_opt pdpe1gb rdtscp lm constant_tsc rep_good nopl nonstop_tsc cpuid extd_apicid aperfmperf pni pclmulqdq monitor ssse3 fma cx16 pcid sse4_1 sse4_2 movbe popcnt aes xsave avx f16c rdrand lahf_lm cmp_legacy svm extapic cr8_legacy abm sse4a misalignsse 3dnowprefetch osvw ibs skinit wdt tce topoext perfctr_core perfctr_nb bpext perfctr_llc mwaitx cpb cat_l3 cdp_l3 invpcid_single hw_pstate ssbd mba ibrs ibpb stibp vmmcall fsgsbase bmi1 avx2 smep bmi2 erms invpcid cqm rdt_a rdseed adx smap clflushopt clwb sha_ni xsaveopt xsavec xgetbv1 xsaves cqm_llc cqm_occup_llc cqm_mbm_total cqm_mbm_local clzero irperf xsaveerptr rdpru wbnoinvd amd_ppin arat npt lbrv svm_lock nrip_save tsc_scale vmcb_clean flushbyasid decodeassists pausefilter pfthreshold v_vmsave_vmload vgif umip pku ospke vaes vpclmulqdq rdpid overflow_recov succor smca fsrm
# bugs		: sysret_ss_attrs spectre_v1 spectre_v2 spec_store_bypass
# bogomips	: 6388.35
# TLB size	: 2560 4K pages
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 48 bits physical, 48 bits virtual
# power management: ts ttp tm hwpstate cpb eff_freq_ro [13] [14]

# %% [markdown]
# # Step 4 :  Use the list of systems of Step 1 and the code of Step 2 to extract all the systems
#
# Goal : get a dataframe for each system (eg the one for x264 displayed in step 2)

# %% [markdown]
# uncomment the following cell if you want to download the data
#
#
# requires to run step 1 first

# %% [markdown]
# urls = df["url"]
#
# for u in urls:
#     split_url = u.split("/")
#     name = split_url[4] + "-" + split_url[5]
#     e = ExtractorTP(u)
#     try:
#         e.extract_data().to_csv("./data/systems/"+name+".csv")
#     except:
#         print(u)

# %% [markdown]
# # Step 5 :  Use the list of processor tested on the systems in Step 4 and extract all the informations
#
# Goal : get metadata for each processor (eg the one for AMD EPYC 74F3 24-Core displayed in step 3)

# %%
prof_dir = "./data/systems/"

procs = []

for f in os.listdir(prof_dir):
    df = pd.read_table(prof_dir+f, sep=',', index_col = 0)
    for d in df["idproc"]:
        if d not in procs:
            procs.append(d)
# Out:
# ['/s/AMD+Ryzen+5+5600X+6-Core',
#  '/s/Intel+Core+i9-11900K',
#  '/s/AMD+Ryzen+9+5950X+16-Core',
#  '/s/AMD+Ryzen+7+5800X+8-Core',
#  '/s/AMD+Ryzen+9+5900X+12-Core']

# %% [markdown]
# Extract all metadata

# %%
prefix_urls = "https://openbenchmarking.org"

no_info_urls = []
    
for i in range(len(procs)):
    
    p = procs[i]
    proc_url = prefix_urls+p
    proc_name = p.replace("/s/", "").replace("+", "")
    proc_dir = "./data/procs/" + proc_name + "/"
    
    
    try:
        ext = ExtractorPROC(proc_url)
        catproc, lscpu = ext.extract_data()

        if not os.path.isdir(proc_dir):
            os.mkdir(proc_dir)

        with open(proc_dir+"catproc.txt", "w") as t:
            t.write(catproc)

        with open(proc_dir+"lscpu.txt", "w") as t:
            t.write(lscpu)

        print("Done with :", proc_url)
        
    except:
        no_info_urls.append(proc_url)
        print("No information with : ", proc_url)
# Out:
# Done with : https://openbenchmarking.org/s/AMD+Ryzen+5+5600X+6-Core
# Done with : https://openbenchmarking.org/s/Intel+Core+i9-11900K
# Done with : https://openbenchmarking.org/s/AMD+Ryzen+9+5950X+16-Core
# Done with : https://openbenchmarking.org/s/AMD+Ryzen+7+5800X+8-Core
# Done with : https://openbenchmarking.org/s/AMD+Ryzen+9+5900X+12-Core
# Done with : https://openbenchmarking.org/s/Intel+Core+i5-11600K
# Done with : https://openbenchmarking.org/s/Intel+Core+i9-10900K
# Done with : https://openbenchmarking.org/s/Intel+Core+i9-9900K
# Done with : https://openbenchmarking.org/s/Intel+Core+i5-10600K
# Done with : https://openbenchmarking.org/s/AMD+Ryzen+9+3900XT+12-Core
# Done with : https://openbenchmarking.org/s/AMD+Ryzen+5+5600G
# Done with : https://openbenchmarking.org/s/AMD+Ryzen+9+3950X+16-Core
# Done with : https://openbenchmarking.org/s/AMD+Ryzen+3+3300X+4-Core
# Done with : https://openbenchmarking.org/s/AMD+Ryzen+Threadripper+3970X+32-Core
# Done with : https://openbenchmarking.org/s/AMD+Ryzen+7+5700G
# Done with : https://openbenchmarking.org/s/AMD+Ryzen+9+3900X+12-Core
# Done with : https://openbenchmarking.org/s/AMD+Ryzen+5
# Done with : https://openbenchmarking.org/s/2+x+Intel+Xeon+Gold+6130
# Done with : https://openbenchmarking.org/s/2+x+Intel+Xeon+Gold+6230
# Done with : https://openbenchmarking.org/s/Intel+Core+i7-8700
# Done with : https://openbenchmarking.org/s/Intel+Xeon+E5-2620+v3
# Done with : https://openbenchmarking.org/s/Intel+Core+i7-7700T
# Done with : https://openbenchmarking.org/s/Intel+Xeon+W3530
# No information with :  https://openbenchmarking.org/s/Intel+Core+i5-7267U
# Done with : https://openbenchmarking.org/s/Intel+Core+i7+740Q
# No information with :  https://openbenchmarking.org/s/ARMv8+Cortex-A73+8-Core
# Done with : https://openbenchmarking.org/s/ARMv8+rev+3+6-Core
# Done with : https://openbenchmarking.org/s/Loongson-3A+R4
# Done with : https://openbenchmarking.org/s/ARMv8+rev+1+4-Core
# Done with : https://openbenchmarking.org/s/Intel+Atom+E3845
# Done with : https://openbenchmarking.org/s/Intel+Core+2+Duo+T7100
# No information with :  https://openbenchmarking.org/s/AMD+Athlon+X2+BE-2300
# Done with : https://openbenchmarking.org/s/ARMv7+rev+5+4-Core
# No information with :  https://openbenchmarking.org/s/960GB+INTEL+SSDPED1D960GAY
# No information with :  https://openbenchmarking.org/s/800GB+INTEL
# No information with :  https://openbenchmarking.org/s/4+x+2048GB+MR9460-16i
# No information with :  https://openbenchmarking.org/s/4+x+1000GB+INTEL+SSDPELKX010T8
# No information with :  https://openbenchmarking.org/s/4+x+1024GB+KXG60ZNV1T02+TOSHIBA
# No information with :  https://openbenchmarking.org/s/2396GB+MR9271-8i
# No information with :  https://openbenchmarking.org/s/2396GB+MR9266-8i
# No information with :  https://openbenchmarking.org/s/80GB+INTEL+SSDSCKGW08
# No information with :  https://openbenchmarking.org/s/2+x+32GB+SATA+SSD
# No information with :  https://openbenchmarking.org/s/1000GB+Force+MP600
# No information with :  https://openbenchmarking.org/s/8+x+300GB+H106030SDSUN300G
# No information with :  https://openbenchmarking.org/s/256GB+TOSHIBA-RD400
# No information with :  https://openbenchmarking.org/s/Force+MP600
# No information with :  https://openbenchmarking.org/s/1000GB+Western+Digital+WD_BLACK+SN850+1TB
# No information with :  https://openbenchmarking.org/s/2398GB+HW-SAS3508
# No information with :  https://openbenchmarking.org/s/20+x+500GB+Samsung+SSD+860
# No information with :  https://openbenchmarking.org/s/120GB+SSDSCKJB120G7R
# No information with :  https://openbenchmarking.org/s/32GB+TS32GMSA510
# No information with :  https://openbenchmarking.org/s/512GB+INTEL+SSDPEKNW512G8
# No information with :  https://openbenchmarking.org/s/250GB+Tech
# No information with :  https://openbenchmarking.org/s/20+x+ATA+Samsung+SSD+860+1B6Q
# No information with :  https://openbenchmarking.org/s/238GB+INTEL+SSDPEKKW256G8
# No information with :  https://openbenchmarking.org/s/238GB+NVMe+INTEL+SSDPEKKW25
# No information with :  https://openbenchmarking.org/s/2+x+932GB+WDC+WD10EZEX-00BN5A0
# Done with : https://openbenchmarking.org/s/2+x+Intel+Xeon+Platinum+8168
# Done with : https://openbenchmarking.org/s/2+x+Intel+Xeon+Gold+6152
# Done with : https://openbenchmarking.org/s/2+x+Intel+Xeon+E5-2699+v3
# Done with : https://openbenchmarking.org/s/2+x+Intel+Xeon+E5-2698+v3
# Done with : https://openbenchmarking.org/s/2+x+AMD+EPYC+7551+32-Core
# Done with : https://openbenchmarking.org/s/Intel+Core+i7-4750HQ
# Done with : https://openbenchmarking.org/s/2+x+Intel+Xeon+E5-2680+v3
# Done with : https://openbenchmarking.org/s/2+x+Intel+Xeon+E5-2669+v3
# Done with : https://openbenchmarking.org/s/AMD+EPYC+7551P+32-Core
# Done with : https://openbenchmarking.org/s/Intel+Core+i5-2400S
# Done with : https://openbenchmarking.org/s/Intel+Core+i3-2120
# Done with : https://openbenchmarking.org/s/AMD+FX-9590+Eight-Core
# Done with : https://openbenchmarking.org/s/4+x+Intel+Xeon+E5-4650+0
# Done with : https://openbenchmarking.org/s/Intel+Core+i7-3517UE
# Done with : https://openbenchmarking.org/s/Intel+Core+i7+860
# Done with : https://openbenchmarking.org/s/AMD+FX-8320E+Eight-Core
# Done with : https://openbenchmarking.org/s/2+x+Intel+Xeon+E5-
# Done with : https://openbenchmarking.org/s/Intel+Xeon+Platinum+8163
# No information with :  https://openbenchmarking.org/s/Intel+Xeon+E5-2686+v4
# Done with : https://openbenchmarking.org/s/2+x+AMD+Opteron+6238
# Done with : https://openbenchmarking.org/s/C-QuadCore+C4600
# Done with : https://openbenchmarking.org/s/MSI+NVIDIA+GeForce+RTX+3070
# Done with : https://openbenchmarking.org/s/Intel+Xeon+Platinum+8259CL
# Done with : https://openbenchmarking.org/s/4+x+AMD+Opteron+6378
# Done with : https://openbenchmarking.org/s/Intel+Xeon+E3-1275L+v3
# Done with : https://openbenchmarking.org/s/AMD+Athlon+X4+750K+Quad+Core
# Done with : https://openbenchmarking.org/s/AMD+Ryzen+Threadripper+PRO+3995WX+64-Cores
# No information with :  https://openbenchmarking.org/s/8+x+16384+MB+DDR4-2667MT
# No information with :  https://openbenchmarking.org/s/4+x+16384+MB+DDR4-3600MT
# No information with :  https://openbenchmarking.org/s/2+x+8192+MB+DDR3-1333MT
# No information with :  https://openbenchmarking.org/s/4+x+64+GB+DDR4-2933MT
# No information with :  https://openbenchmarking.org/s/6+x+64+GB+DDR4-2933MT
# No information with :  https://openbenchmarking.org/s/1+x+8192+MB+DDR4-2400MHz+HMA81GS6AFR8N-UH
# No information with :  https://openbenchmarking.org/s/12+x+16384+MB+DDR4-2933MT
# No information with :  https://openbenchmarking.org/s/8+x+16384+MB+2133MHz+Samsung+M393A2G40DB0-CPB
# No information with :  https://openbenchmarking.org/s/8+x+16384+MB+2133MHz+Samsung+M393A2G40EB1-CRC
# No information with :  https://openbenchmarking.org/s/4+x+32+GB+2400MHz+Samsung+M393A4K40BB1-CRC
# No information with :  https://openbenchmarking.org/s/16+x+8192+MB+1866MHz+Samsung+M393A1G40DB0-CPB
# No information with :  https://openbenchmarking.org/s/1+x+16384+MB+DDR4-2133MT
# Done with : https://openbenchmarking.org/s/2+x+Intel+Xeon+E5606
# Done with : https://openbenchmarking.org/s/Intel+Celeron+1007U
# Done with : https://openbenchmarking.org/s/Intel+Pentium+Dual+T3200
# Done with : https://openbenchmarking.org/s/4+x+Intel+Xeon+X7350
# Done with : https://openbenchmarking.org/s/Intel+Core+i7-2677M
# Done with : https://openbenchmarking.org/s/VIA+Nano+X2+C4350AL
# Done with : https://openbenchmarking.org/s/AMD+Athlon+II+170u
# Done with : https://openbenchmarking.org/s/Intel+Core+2+Duo+E7400
# Done with : https://openbenchmarking.org/s/Zotac+NVIDIA+GeForce+RTX+3090
# Done with : https://openbenchmarking.org/s/Intel+Core+i7-4870HQ
# Done with : https://openbenchmarking.org/s/2+x+Intel+Xeon+E5-2637+v2
# Done with : https://openbenchmarking.org/s/Intel+Core+i5-4200M
# Done with : https://openbenchmarking.org/s/Intel+Core+i3-4370
# Done with : https://openbenchmarking.org/s/Intel+Xeon+X5690
# No information with :  https://openbenchmarking.org/s/Intel+Core+i3-5015U
# Done with : https://openbenchmarking.org/s/Intel+Xeon+E5-2609+0
# Done with : https://openbenchmarking.org/s/2+x+Intel+Xeon+E5-26xx+v3
# Done with : https://openbenchmarking.org/s/Intel+Pentium+E5500
# Done with : https://openbenchmarking.org/s/Intel+Core+2+Duo+E4600
# No information with :  https://openbenchmarking.org/s/Intel+Core+i7+M+620
# Done with : https://openbenchmarking.org/s/8+x+AMD+Opteron+63xx+class
# Done with : https://openbenchmarking.org/s/2+x+Intel+Xeon+E5-2650L+0
# No information with :  https://openbenchmarking.org/s/Pentium+E5200
# Done with : https://openbenchmarking.org/s/Intel+Pentium+T4500
# Done with : https://openbenchmarking.org/s/Intel+Pentium+N3540
# Done with : https://openbenchmarking.org/s/AMD+Athlon+64+X2+5200
# Done with : https://openbenchmarking.org/s/AMD+Phenom+II+X4+973
# Done with : https://openbenchmarking.org/s/Intel+Core+i3-2365M
# Done with : https://openbenchmarking.org/s/2+x+Intel+Xeon+5140
# Done with : https://openbenchmarking.org/s/AMD+Phenom+9550
# Done with : https://openbenchmarking.org/s/Intel+Pentium+D+3.20GHz
# No information with :  https://openbenchmarking.org/s/Mobile+Intel+Pentium+4-+M
# No information with :  https://openbenchmarking.org/s/NVIDIA+GeForce+7300+GT
# Done with : https://openbenchmarking.org/s/NVIDIA+GeForce+9600+GT
# No information with :  https://openbenchmarking.org/s/NVIDIA+Quadro+FX+1600M
# No information with :  https://openbenchmarking.org/s/AMD+Radeon+HD+4830
# No information with :  https://openbenchmarking.org/s/NVIDIA+GeForce+Go+7300
# No information with :  https://openbenchmarking.org/s/AMD+Radeon+HD+4670
# No information with :  https://openbenchmarking.org/s/ASUS+NVIDIA+GeForce+8400+GS
# No information with :  https://openbenchmarking.org/s/Intel+Mobile+945GM
# No information with :  https://openbenchmarking.org/s/AMD+Mobility+Radeon+HD+3400
# No information with :  https://openbenchmarking.org/s/NVIDIA+GeForce+8300+GS
# No information with :  https://openbenchmarking.org/s/NVIDIA+GeForce+GTX+670MX
# No information with :  https://openbenchmarking.org/s/AMD+Radeon+HD+4290
# No information with :  https://openbenchmarking.org/s/ATI+FirePro+V4800
# No information with :  https://openbenchmarking.org/s/NVIDIA+GeForce+6150+LE
# No information with :  https://openbenchmarking.org/s/AMD+Radeon+HD+2600XT
# Done with : https://openbenchmarking.org/s/MSI+AMD+Radeon+HD+5000
# No information with :  https://openbenchmarking.org/s/AMD+Radeon+HD+6530D
# No information with :  https://openbenchmarking.org/s/AMD+Radeon+HD+3450
# No information with :  https://openbenchmarking.org/s/NVIDIA+GeForce+FX+5200
# No information with :  https://openbenchmarking.org/s/AMD+Radeon+HD+4600
# No information with :  https://openbenchmarking.org/s/AMD+Mobility+Radeon+9600+M10
# No information with :  https://openbenchmarking.org/s/AMD+Radeon+HD+6290
# No information with :  https://openbenchmarking.org/s/NVIDIA+GeForce+GT+330M
# No information with :  https://openbenchmarking.org/s/NVIDIA+GeForce2+MX
# No information with :  https://openbenchmarking.org/s/NVIDIA+GeForce4+MX+4000
# No information with :  https://openbenchmarking.org/s/nv17
# No information with :  https://openbenchmarking.org/s/AMD+Radeon+9550
# No information with :  https://openbenchmarking.org/s/AMD+FirePro+2260
# No information with :  https://openbenchmarking.org/s/S3+ProSavage+KM133
# No information with :  https://openbenchmarking.org/s/Intel+Mobile+945GME+IGP
# No information with :  https://openbenchmarking.org/s/VIA+VX900
# No information with :  https://openbenchmarking.org/s/EMGD+on+PowerVR+SGX535
# No information with :  https://openbenchmarking.org/s/S3+Chrome+500
# Done with : https://openbenchmarking.org/s/Matrox+MGA+G200eW+WPCM450
# No information with :  https://openbenchmarking.org/s/NVIDIA+GeForce2+Go
# No information with :  https://openbenchmarking.org/s/Intel+82810E+DC-133
# Done with : https://openbenchmarking.org/s/AMD+GX-424CC+SOC
# Done with : https://openbenchmarking.org/s/2+x+Intel+Xeon+E5-2680+v4
# Done with : https://openbenchmarking.org/s/Intel+Core+i7+980X
# Done with : https://openbenchmarking.org/s/Intel+Xeon+E5-2630L+v2
# Done with : https://openbenchmarking.org/s/Intel+Core+i7+620M
# Done with : https://openbenchmarking.org/s/AMD+Athlon+II+X4+640
# Done with : https://openbenchmarking.org/s/Intel+Core+2+Duo+E8500
# Done with : https://openbenchmarking.org/s/Intel+Xeon+E5-2630L+0
# Done with : https://openbenchmarking.org/s/Intel+Xeon+E5420
# Done with : https://openbenchmarking.org/s/Intel+Pentium+E5300
# Done with : https://openbenchmarking.org/s/Intel+Core+2+Duo+T7300
# Done with : https://openbenchmarking.org/s/AMD+A6-6310+APU+with+AMD+Radeon+R4
# Done with : https://openbenchmarking.org/s/AMD+Athlon+64+3500
# Done with : https://openbenchmarking.org/s/Intel+Celeron+847
# No information with :  https://openbenchmarking.org/s/2+x+4096+MB+DDR3-1600MT
# No information with :  https://openbenchmarking.org/s/2+x+8192+MB+DDR3-1600MHz+Kingston
# No information with :  https://openbenchmarking.org/s/12+x+32+GB+DDR4-2666MT
# No information with :  https://openbenchmarking.org/s/2+x+4096+MB+DDR3-1333MT
# No information with :  https://openbenchmarking.org/s/2+x+4096+MB+1600MHz
# No information with :  https://openbenchmarking.org/s/2+x+4096+MB+2133MHz+Kingston+KHX2400C11D3
# No information with :  https://openbenchmarking.org/s/2+x+4096+MB+1600MHz+Hynix+HMT351S6CFR8C-PB
# No information with :  https://openbenchmarking.org/s/1+x+8192+MB+2400MHz+Samsung+M471A1K43CB1-CRC
# No information with :  https://openbenchmarking.org/s/4+x+4096+MB+2400MHz+Kingston+KHX2400C15D4
# No information with :  https://openbenchmarking.org/s/2+x+2048+MB+SDRAM
# No information with :  https://openbenchmarking.org/s/1+x+2048+MB+DDR3-1333MHz
# No information with :  https://openbenchmarking.org/s/1+x+2048+MB+DDR3-1333MHz+Kingston
# No information with :  https://openbenchmarking.org/s/12+x+32768+MB+2933MHz+HMA84GR7CJR4N-WM
# No information with :  https://openbenchmarking.org/s/1+x+2048+MB+DDR3-1600MHz+00000000
# No information with :  https://openbenchmarking.org/s/4093GB+database
# No information with :  https://openbenchmarking.org/s/1000GB+Samsung+SSD+860
# No information with :  https://openbenchmarking.org/s/480GB+INTEL+SSDSC2BB48
# No information with :  https://openbenchmarking.org/s/3999GB+DISK_RAID0
# No information with :  https://openbenchmarking.org/s/1000GB+Seagate+ST1000DM010-2EP1
# No information with :  https://openbenchmarking.org/s/2000GB+SMC3108
# No information with :  https://openbenchmarking.org/s/128GB+CORSAIR+CMFSSD-1
# No information with :  https://openbenchmarking.org/s/900GB+Seagate+ST900MM0026
# No information with :  https://openbenchmarking.org/s/1000GB+Western+Digital+WD10EZEX-00W
# No information with :  https://openbenchmarking.org/s/500GB+Hitachi+HDS72105
# No information with :  https://openbenchmarking.org/s/1000GB+PERC+6
# No information with :  https://openbenchmarking.org/s/500GB+Seagate+ST500DM002-1BD14
# No information with :  https://openbenchmarking.org/s/1000GB+Seagate+ST31000524AS
# No information with :  https://openbenchmarking.org/s/500GB+SAMSUNG+HD502HI
# No information with :  https://openbenchmarking.org/s/1000GB+Seagate+ST1000LM024+HN-M
# No information with :  https://openbenchmarking.org/s/250GB+Western+Digital+WD2500AAJS-7
# No information with :  https://openbenchmarking.org/s/320GB+Hitachi+HTS54503
# No information with :  https://openbenchmarking.org/s/160GB+Seagate+ST3160812AS

# %%
len(no_info_urls)
# Out:
# 1330

# %%
len(procs)
# Out:
# 2786

# %% [markdown]
# #### export neo4j

# %%
sys_dir = "./data/systems/"

df_final = pd.DataFrame()

for sys_name in os.listdir(sys_dir):
    df = pd.read_table(sys_dir+sys_name, sep=',', index_col = 0)
    df["sys"] = sys_name[:-4]
    df_final = pd.concat([df_final,df])
    
df_final
# Out:
#                           idproc                   descproc percentile  \
# 0    /s/AMD+Ryzen+5+5600X+6-Core   AMD Ryzen 5 5600X 6-Core       98th
# 1        /s/Intel+Core+i9-11900K       Intel Core i9-11900K       91st
# 2   /s/AMD+Ryzen+9+5950X+16-Core  AMD Ryzen 9 5950X 16-Core       91st
# 3    /s/AMD+Ryzen+7+5800X+8-Core   AMD Ryzen 7 5800X 8-Core       90th
# 4   /s/AMD+Ryzen+9+5900X+12-Core  AMD Ryzen 9 5900X 12-Core       90th
# ..                           ...                        ...        ...
# 22        /s/Intel+Core+i7-5775C        Intel Core i7-5775C       27th
# 24        /s/Intel+Core+i7-4790K        Intel Core i7-4790K       17th
# 25         /s/Intel+Core+i5-3470         Intel Core i5-3470       14th
# 26         /s/Intel+Core+i3-8100         Intel Core i3-8100       14th
# 27        /s/Intel+Core+i7-4960X        Intel Core i7-4960X       11th
#
#     nbproc          perf           sys
# 0        6            39       pts-git
# 1       10      40 +/- 2       pts-git
# 2       34      40 +/- 4       pts-git
# 3       15      40 +/- 4       pts-git
# 4       27      41 +/- 5       pts-git
# ..     ...           ...           ...
# 22       3  31.2 +/- 1.2  pts-smhasher
# 24       4  33.4 +/- 0.1  pts-smhasher
# 25       3          33.6  pts-smhasher
# 26       3          33.9  pts-smhasher
# 27       3          34.2  pts-smhasher
#
# [29032 rows x 6 columns]

# %%
df_final.to_csv("final_neo4j.csv")

# %%
pd.DataFrame(pd.Series(df_final["descproc"]).unique()).to_csv("procs.csv")

# %%
pd.DataFrame(pd.Series(df_final["sys"]).unique()).to_csv("system.csv")

# %%
import numpy as np
import os
import itertools

def isfloat(value):
    try:
        float(value)
        return True
    except ValueError:
        return False

check_units= ['',
 u'GHz',
 u'KB',
 u'KB',
 u'MB',
 u'GB/sec',
 u'GB/sec',
 u'MB/sec',
 u'GB/sec',
 u'MB/sec',
 u'GB/sec',
 u'MB/sec',
 u'MB/sec',
 u'MB/sec',
 u'MB/sec',
 u'MB/sec',
 u'MB/sec',
 u'Mpixels/sec',
 u'Mpixels/sec',
 u'Mpixels/sec',
 u'Mpixels/sec',
 u'Mpixels/sec',
 u'Mpixels/sec',
 u'Mpixels/sec',
 u'Mpixels/sec',
 u'Mpixels/sec',
 u'Mpixels/sec',
 u'MB/sec',
 u'MB/sec',
 u'Mpairs/sec',
 u'Mpairs/sec',
 u'Mnodes/sec',
 u'Mnodes/sec',
 u'Gflops',
 u'Gflops',
 u'Gflops',
 u'Gflops',
 u'Gflops',
 u'Gflops',
 u'Gflops',
 u'Gflops',
 u'Gflops',
 u'Gflops',
 u'Gflops',
 u'Gflops',
 u'Gflops',
 u'Gflops',
 u'Mpairs/sec',
 u'Mpairs/sec',
 u'Mpixels/sec',
 u'Mpixels/sec',
 u'GB/sec',
 u'GB/sec',
 u'GB/sec',
 u'GB/sec',
 u'GB/sec',
 u'GB/sec',
 u'GB/sec',
 u'GB/sec']

geek_data = [] # model #, freq, L2, L3, memory, bench, single/multicore, score, perf

path = '../cpu_selection-master/'
files = os.listdir(path)
for file in files:
    units = []
    for i in range(5):
        units.append(0)
    
    data = []
    if not isfloat(file.split('.')[0]):
        continue
    soup = BeautifulSoup(open(os.path.join(path, file)))
    tables = soup.find_all('table', attrs={'class':'table table-striped geekbench2-show system-information'})
    table_body = tables[1].find('tbody')
    rows = table_body.find_all('tr')
    data_t = []
    for row in rows:
        cols = row.find_all('td')
        if len(cols) == 0:
            cols = row.find_all('th')
        cols = [ele.text.strip() for ele in cols]
        data_t.append([ele.replace('\n',' ').replace('  ',' ') for ele in cols if ele]) 
    #print arch
    data.append(data_t)
    
    tables = soup.find_all('table', attrs={'class':'table table-striped geekbench2-show section-performance'})
    for table in tables:
        table_body = table.find('tbody')
        rows = table_body.find_all('tr')
        data_t = []
        for row in rows:
            cols = row.find_all('td')
            if len(cols) == 0:
                cols = row.find_all('th')
            cols = [ele.text.strip() for ele in cols]
            data_t.append([ele.replace('\n',' ').replace('  ',' ') for ele in cols if ele]) 
        #print arch
        data.append(data_t)
    head = []
    head.append(0)
    head.append(0)
    head.append(0)
    head.append(0)
    head.append(0)

    for d in data[0]:
        if d[0] == 'Processor':
            head[0] = d[1].split('@')[0].strip(' ')
            head[1] = float(d[1].split('@')[1].strip(' ').split(' ')[0])
            
            units[0] = ''
            units[1] = d[1].split('@')[1].strip(' ').split(' ')[1]
            if 'M' in units[1]:
                head[1] = 0.001* float(d[1].split('@')[1].strip(' ').split(' ')[0])
                units[1] = d[1].split('@')[1].strip(' ').split(' ')[1].replace('M','G')

            
        elif d[0] == 'L2 Cache':
            head[2] = d[1]
            units[2] = d[1].split(' ')[1]
        elif d[0] == 'L3 Cache':
            if 'KB' in d[1]:
                head[3] = float(d[1].split(' ')[0])
                units[3] = d[1].split(' ')[1]

        elif d[0] == 'Memory':
            if 'MB' in d[1]:
                head[4] = float(d[1].split(' ')[0])
                units[4] = d[1].split(' ')[1]

  
    for i in range(1, len(data)):
        data_current = data[i]
        for d in data_current:
            data_t = []
            for t in head:
                data_t.append(t)

            if len(d[0].split(' ')) == 3:
                data_t.append(d[0].split(' ')[0] + ' ' + d[0].split(' ')[1])
            elif len(d[0].split(' ')) == 2:
                data_t.append(d[0].split(' ')[0])
            else:
                print(d)
            
            if 'Single' in d[0].split(' ')[-1]:
                data_t.append(0)
            elif 'Mult' in d[0].split(' ')[-1]:
                data_t.append(1)
                
            data_t.append(d[1].split(' ')[0])
            
            units.append(d[1].split(' ')[-1])
            if 'G' in check_units[len(units)-1] and 'M' in units[-1]:
                data_t.append(0.001*float(d[1].split(' ')[1]))
                units[-1] = d[1].split(' ')[-1].replace('M','G')
            elif 'M' in check_units[len(units)-1] and 'G' in units[-1]:
                data_t.append(1000*float(d[1].split(' ')[1]))
                units[-1] = d[1].split(' ')[-1].replace('G','M')
            elif 'M' in check_units[len(units)-1] and 'K' in units[-1]:
                data_t.append(0.001*float(d[1].split(' ')[1]))
                units[-1] = d[1].split(' ')[-1].replace('K','M')
            elif 'G' in check_units[len(units)-1] and 'K' in units[-1]:
                data_t.append(0.000001*float(d[1].split(' ')[1]))
                units[-1] = d[1].split(' ')[-1].replace('K','G')
            elif 'G' in check_units[len(units)-1] and 'T' in units[-1]:
                data_t.append(1000*float(d[1].split(' ')[1]))
                units[-1] = d[1].split(' ')[-1].replace('T','G')
            else:
                data_t.append(d[1].split(' ')[1])
                units[-1] = d[1].split(' ')[-1]
            geek_data.append(data_t)
            
    # check units
    for i in range(len(check_units)):
        if check_units[i] != units[i]:
            print(file, i, check_units[i], units[i])

import json
with open('geek_data.json','w') as outfile:
    json.dump(geek_data, outfile)
